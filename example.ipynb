# %%
from EquityPricer import *
from datetime import datetime

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
google_test = yf.download("GOOG", start='2010-01-01')['Adj Close']
nasdaq = yf.download("^IXIC", start='2007-01-01')['Adj Close']
pricer = Long_Short_Comb(google_test, nasdaq)
result = pricer.get_estimate_series()
google = yf.download('GOOG', start='2007-01-01')["Adj Close"]
google = np.log(google/google.shift(1)).dropna()
result = pd.concat([result, google], axis=1)
result = result[result.index <= datetime(2007,12,31)]
result
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#             Adj Close  Adj Close
# Date
# 2007-01-04   0.012288   0.032963
# 2007-01-05  -0.007703   0.008099
# 2007-01-08   0.001639  -0.007437
# 2007-01-09   0.002315   0.003962
# 2007-01-10   0.006278   0.008123
# ...               ...        ...
# 2007-12-24   0.007892   0.005782
# 2007-12-26   0.003999   0.014325
# 2007-12-27  -0.017358  -0.014310
# 2007-12-28  -0.000819   0.002551
# 2007-12-31  -0.008176  -0.015854
#
# [250 rows x 2 columns]

# %%
result.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pricer.get_beta_hat()
# Out:
# 0.9866067956367041

# %%
pricer.get_short_cov()
# Out:
#           index     stock
# index  0.038340  0.037826
# stock  0.037826  0.067458
